# %%
# importation de la classe ImprovedClientClass à partir du fichier 'class_python_project.py'
from class_python_project import ImprovedClientClass

# %%
# clé API Binance
public_key = 'CcGM6Y7zKV2f42HmleqKR9YK9QfFiddhMN5DZIJ06G7W1cxS1V3YYFvEWk9R4toc'
private_key = 'ZDBlXkjEslbrfAKw6fMFO0P8JYYzN6SQWJoaFYQnTDWKVLGv0N3h8CaNlhOtjmht'
# création d'une instance de la classe ImprovedClientClass
user = ImprovedClientClass(public_key, private_key)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
# ...

# %%
# création d'une instance de la classe ImprovedClientClass
user = ImprovedClientClass(public_key, private_key)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
# ...

# %%
# data rentrée par l'utilisateur
symbol = 'ETHUSDT'
symbols = ["BTCUSDT", "ETHUSDT"]
interval = '1h'
inter = client.KLINE_INTERVAL_1HOUR
startdate = "01/01/22 10:00:00"
enddate = "01/01/22 13:59:59"
limit = 1000
# type de contrat : rentrer n'importe quelle autre chaine que 'futures' pour avoir les spots
contract_type = 'futures'
# suivant la méthode de la classe utilisée, il peut être mieux d'adapter les intervalles ou les dates
# de début et de fin pour ne pas que l'exécution sature

# %%
# récupérer les bougies pour la paire et la fréquence choisie, de la date de début à la date de fin
recupcustombars = user.get_custom_bars(symbol, interval, startdate, enddate, limit)
print(recupcustombars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/01/1bzxktkn2570y7jdfj2khflc0000gn/T/ipykernel_50257/3621302761.py in <module>
#       1 # récupérer les bougies pour la paire et la fréquence choisie, de la date de début à la date de fin
# ----> 2 recupcustombars = user.get_custom_bars(symbol, interval, startdate, enddate, limit)
#       3 print(recupcustombars)
#
# NameError: name 'user' is not defined

# %%
# récuperer les bougies des paires contenues dans la liste 'symbols' pour la fréquence choisie,
# de la date de début à la date de fin
recupsymbolsbars = client.get_symbols_bars(symbols, inter, startdate, enddate, limit=1000)
print(recupsymbolsbars)

# %%
# récupérer soit les futures soit les spots correspondant aux arguments, en fonction du type de contrat choisi
futuresorspots = client.get_futures_or_spots(symbol, inter, startdate, enddate, limit, contract_type)
print(futuresorspots)
